# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree

# %%
inspections = pd.read_csv('C:\\Users\\sambo\\Downloads\\final_engineered_features.csv')
# Out:
# C:\Users\sambo\AppData\Local\Temp\ipykernel_43116\2659653593.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   inspections = pd.read_csv('C:\\Users\\sambo\\Downloads\\final_engineered_features.csv')

# %%
inspections.sample(10)
# Out:
#         FEI Number                                Legal Name          City  \
# 94781   1000512361      Bora Pharmaceuticals Injectables Inc     Baltimore
# 209511  3006534564          Rastelli Global Enterprises, LLC    Swedesboro
# 197536  3005501497                   Anulex Technologies Inc  Eden Prairie
# 27136      1580974           Rothenbuhler Cheesemakers, Inc.   Middlefield
# 40387      1914094              Kellanova Manufacturing, LLC   Kansas City
# 292544  3013544730                  Diamonds Trading Co, LLC   Garden City
# 92057   1000306115                             ErgoMed, Inc.   San Antonio
# 142114  3003468567                 LoRu Grain Warehouse, LLC   Worthington
# 296458  3014243028                Gangnam Severance Hospital         Seoul
# 27080      1574562  Louis Stokes Cleveland VA Medical Center     Cleveland
#
#              State    Zip             Country/Area  Fiscal Year  \
# 94781     Maryland  21230            United States         2009
# 209511  New Jersey  08085            United States         2016
# 197536   Minnesota  55344            United States         2010
# 27136         Ohio  44062            United States         2009
# 40387       Kansas  66115            United States         2020
# 292544    Michigan  48135            United States         2025
# 92057        Texas  78249            United States         2022
# 142114   Minnesota  56187            United States         2010
# 296458           -      -  Korea (the Republic of)         2018
# 27080         Ohio  44106            United States         2024
#
#         Inspection ID Posted Citations Inspection End Date  ...  \
# 94781          608105               No          2009-08-27  ...
# 209511         974131               No          2016-05-11  ...
# 197536         680312              Yes          2010-09-22  ...
# 27136          603817               No          2009-08-11  ...
# 40387         1120271               No          2020-01-28  ...
# 292544        1251445               No          2024-10-09  ...
# 92057         1156173              Yes          2021-11-05  ...
# 142114         638249               No          2010-01-12  ...
# 296458        1057724               No          2018-04-25  ...
# 27080         1227653               No          2024-01-05  ...
#
#                FMD-145 Date recalled_bool classification_flag inspection_year  \
# 94781                     -             0                   0            2009
# 209511                    -             0                   0            2016
# 197536                    -             0                   1            2010
# 27136                     -             0                   0            2009
# 40387   2020-04-24 00:00:00             0                   0            2020
# 292544  2025-03-03 00:00:00             0                   0            2024
# 92057   2023-01-10 00:00:00             0                   1            2021
# 142114                    -             0                   0            2010
# 296458                    -             0                   0            2018
# 27080   2024-01-26 00:00:00             0                   0            2024
#
#        inspection_month  inspection_dayofweek  inspection_quarter  \
# 94781                 8                     3                   3
# 209511                5                     2                   2
# 197536                9                     2                   3
# 27136                 8                     1                   3
# 40387                 1                     1                   1
# 292544               10                     2                   4
# 92057                11                     4                   4
# 142114                1                     1                   1
# 296458                4                     2                   2
# 27080                 1                     4                   1
#
#         week_of_year  inspection_season  days_since_last_inspection
# 94781             35             Summer                        -1.0
# 209511            19             Spring                      1539.0
# 197536            38               Fall                       167.0
# 27136             33             Summer                       144.0
# 40387              5             Winter                      1048.0
# 292544            41               Fall                       286.0
# 92057             44               Fall                       805.0
# 142114             2             Winter                        -1.0
# 296458            17             Spring                        -1.0
# 27080              1             Winter                      1541.0
#
# [10 rows x 24 columns]

# %%
X = inspections.drop(['recalled_bool','classification_flag','Legal Name','City','Zip','FEI Number','Additional Details','FMD-145 Date','Inspection ID','Inspection End Date'], axis=1) 
y = inspections['recalled_bool']

# %%
X.sample(5)
# Out:
#              State   Country/Area  Fiscal Year Posted Citations  \
# 172567     Indiana  United States         2018               No
# 266224    New York  United States         2017               No
# 5153       Florida  United States         2009               No
# 228818           -          India         2017              Yes
# 71177   California  United States         2024              Yes
#
#                           Classification                  Project Area  \
# 172567         No Action Indicated (NAI)  Foodborne Biological Hazards
# 266224         No Action Indicated (NAI)  Foodborne Biological Hazards
# 5153           No Action Indicated (NAI)      Blood and Blood Products
# 228818  Voluntary Action Indicated (VAI)        Drug Quality Assurance
# 71177   Voluntary Action Indicated (VAI)  Foodborne Biological Hazards
#
#           Product Type  inspection_year  inspection_month  \
# 172567  Food/Cosmetics             2018                 3
# 266224  Food/Cosmetics             2017                 3
# 5153         Biologics             2009                 9
# 228818           Drugs             2017                 6
# 71177   Food/Cosmetics             2023                11
#
#         inspection_dayofweek  inspection_quarter  week_of_year  \
# 172567                     2                   1            10
# 266224                     2                   1            10
# 5153                       0                   3            38
# 228818                     4                   2            23
# 71177                      1                   4            48
#
#        inspection_season  days_since_last_inspection
# 172567            Spring                      2889.0
# 266224            Spring                        -1.0
# 5153                Fall                        -1.0
# 228818            Summer                        -1.0
# 71177               Fall                       158.0

# %%
categorical_cols = ['Classification', 'Project Area', 'Product Type', 'State', 'Country/Area', 'inspection_season']
X = pd.get_dummies(X, columns = categorical_cols, drop_first = True, dtype = int)
X['Posted Citations'] = X['Posted Citations'].notnull().astype(int)

# %%
X.sample(10)
# Out:
#         Fiscal Year  Posted Citations  inspection_year  inspection_month  \
# 139352         2022                 1             2022                 5
# 290406         2020                 1             2020                 1
# 75757          2015                 1             2015                 2
# 229766         2011                 1             2011                 2
# 175695         2015                 1             2014                11
# 181006         2013                 1             2013                 3
# 200979         2015                 1             2014                10
# 309042         2021                 1             2021                 8
# 214228         2009                 1             2009                 6
# 211643         2012                 1             2012                 2
#
#         inspection_dayofweek  inspection_quarter  week_of_year  \
# 139352                     0                   2            22
# 290406                     2                   1             2
# 75757                      4                   1             8
# 229766                     4                   1             5
# 175695                     3                   4            46
# 181006                     3                   1            13
# 200979                     3                   4            42
# 309042                     3                   3            33
# 214228                     1                   2            24
# 211643                     1                   1             7
#
#         days_since_last_inspection  \
# 139352                         0.0
# 290406                        -1.0
# 75757                        114.0
# 229766                        -1.0
# 175695                        -1.0
# 181006                        -1.0
# 200979                      1150.0
# 309042                        -1.0
# 214228                        -1.0
# 211643                        -1.0
#
#         Classification_Official Action Indicated (OAI)  \
# 139352                                               0
# 290406                                               0
# 75757                                                0
# 229766                                               0
# 175695                                               0
# 181006                                               0
# 200979                                               0
# 309042                                               0
# 214228                                               0
# 211643                                               0
#
#         Classification_Voluntary Action Indicated (VAI)  ...  \
# 139352                                                0  ...
# 290406                                                1  ...
# 75757                                                 0  ...
# 229766                                                0  ...
# 175695                                                0  ...
# 181006                                                0  ...
# 200979                                                0  ...
# 309042                                                0  ...
# 214228                                                0  ...
# 211643                                                0  ...
#
#         Country/Area_United States  Country/Area_Uruguay  \
# 139352                           1                     0
# 290406                           0                     0
# 75757                            1                     0
# 229766                           1                     0
# 175695                           0                     0
# 181006                           1                     0
# 200979                           1                     0
# 309042                           1                     0
# 214228                           1                     0
# 211643                           1                     0
#
#         Country/Area_Vanuatu  Country/Area_Venezuela  Country/Area_Vietnam  \
# 139352                     0                       0                     0
# 290406                     0                       0                     1
# 75757                      0                       0                     0
# 229766                     0                       0                     0
# 175695                     0                       0                     0
# 181006                     0                       0                     0
# 200979                     0                       0                     0
# 309042                     0                       0                     0
# 214228                     0                       0                     0
# 211643                     0                       0                     0
#
#         Country/Area_Western Samoa  Country/Area_Zimbabwe  \
# 139352                           0                      0
# 290406                           0                      0
# 75757                            0                      0
# 229766                           0                      0
# 175695                           0                      0
# 181006                           0                      0
# 200979                           0                      0
# 309042                           0                      0
# 214228                           0                      0
# 211643                           0                      0
#
#         inspection_season_Spring  inspection_season_Summer  \
# 139352                         1                         0
# 290406                         0                         0
# 75757                          0                         0
# 229766                         0                         0
# 175695                         0                         0
# 181006                         1                         0
# 200979                         0                         0
# 309042                         0                         1
# 214228                         0                         1
# 211643                         0                         0
#
#         inspection_season_Winter
# 139352                         0
# 290406                         1
# 75757                          1
# 229766                         1
# 175695                         0
# 181006                         0
# 200979                         0
# 309042                         0
# 214228                         0
# 211643                         1
#
# [10 rows x 237 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
classifier = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
scores = cross_val_score(
    classifier, X_train, y_train, cv=5, scoring='accuracy')
scores
# Out:
# array([0.94411543, 0.94447315, 0.94473151, 0.94421479, 0.94417505])

# %%
classifier_final = RandomForestClassifier(n_estimators=100, random_state=42)
classifier_final.fit(X_train, y_train)
# y_pred = classifier_final.predict(X_test)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Extract an individual decision tree from the Random Forest
individual_tree = classifier_final.estimators_[0]  # Get the first tree 

# Visualize the decision tree using Matplotlib's plot_tree method
plt.figure(figsize=(12, 8))
plot_tree(individual_tree)
plt.show()

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy * 100:.2f}%')

conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', cbar=False, 
            xticklabels=iris.target_names, yticklabels=iris.target_names)

plt.title('Confusion Matrix Heatmap')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 accuracy = accuracy_score(y_test, y_pred)
#       2 print(f'Accuracy: {accuracy * 100:.2f}%')
#       4 conf_matrix = confusion_matrix(y_test, y_pred)
#
# NameError: name 'accuracy_score' is not defined
